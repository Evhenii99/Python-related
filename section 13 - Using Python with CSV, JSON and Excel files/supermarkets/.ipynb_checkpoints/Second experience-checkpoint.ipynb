# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx")
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6=pandas.read_csv("data.txt", header = None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns = ["ID", "Address", "City", "ZIP", "Country", "Name", "Employees"]
df6
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.set_index("ID")
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=df6.set_index("ID")
df7
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.loc["3":"5","City":"ZIP"]
# Out:
#              City               ZIP
# ID
# 3   San Francisco  California 94114
# 4   San Francisco          CA 94114
# 5   San Francisco        California

# %%
list(df7.loc["3":"5","ZIP"])
# Out:
# ['California 94114', 'CA 94114', 'California']

# %%
df7
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.iloc[3,1:4]
# Out:
# City       San Francisco
# ZIP             CA 94114
# Country              USA
# Name: 4, dtype: object

# %%
df7
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.drop("City",1)
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\3298495432.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop("City",1)
#             Address               ZIP Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df7
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.drop(3,0)
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\4178561526.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(3,0)
#             Address           City         ZIP Country         Name  Employees
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA      Madeira          8
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop         15
# 4      3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7=df7.drop(3,0)
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\2340058592.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7=df7.drop(3,0)

# %%
df7
# Out:
#             Address           City         ZIP Country         Name  Employees
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA      Madeira          8
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop         15
# 4      3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7.drop(df7.index[0:3],0)
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\4142530650.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.index[0:3],0)
#             Address           City         ZIP Country        Name  Employees
# ID
# 5   1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7.drop(df7.columns[0:3],1)
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\2806056389.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.columns[0:3],1)
#    Country         Name  Employees
# ID
# 1      USA      Madeira          8
# 2      USA  Bready Shop         15
# 4      USA   Ben's Shop         10
# 5      USA      Sanchez         12
# 6      USA   Richvalley         20

# %%
df7
# Out:
#             Address           City         ZIP Country         Name  Employees
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA      Madeira          8
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop         15
# 4      3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7["Continent"]=df7.shape[0]*["North America"]

# %%
df7
# Out:
#             Address           City         ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# 4      3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez
# 6   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df7["Continent"]=df7["Country"]+ "," + "North America"

# %%
df7
# Out:
#             Address           City         ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# 4      3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez
# 6   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#     Employees          Continent
# ID
# 1           8  USA,North America
# 2          15  USA,North America
# 4          10  USA,North America
# 5          12  USA,North America
# 6          20  USA,North America

# %%
df7_t=df7.T

# %%
df7_t
# Out:
# ID                         1                  2                  4  \
# Address         3666 21st St     735 Dolores St       3995 23rd St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         5                  6
# Address      1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco
# ZIP               California           CA 94114
# Country                  USA                USA
# Name                 Sanchez         Richvalley
# Employees                 12                 20
# Continent  USA,North America  USA,North America

# %%
df7_t["7"]=["My address","My City","California","My country","My shop",10,"My Continent"]

# %%
df7=df7_t.T

# %%
df7
# Out:
# ID                         1                  2                  4  \
# Address         3666 21st St     735 Dolores St       3995 23rd St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         5                  6            ID             7
# Address      1056 Sanchez St    551 Alvarado St    My address    My address
# City           San Francisco      San Francisco       My City       My City
# ZIP               California           CA 94114    California    California
# Country                  USA                USA    My country    My country
# ...

# %%
df7.drop(df7.columns[5],1)
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\218813699.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.columns[5],1)
# ID                         1                  2                  4  \
# Address         3666 21st St     735 Dolores St       3995 23rd St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         5                  6             7
# Address      1056 Sanchez St    551 Alvarado St    My address
# City           San Francisco      San Francisco       My City
# ...

# %%
df7
# Out:
# ID                         1                  2                  4  \
# Address         3666 21st St     735 Dolores St       3995 23rd St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         5                  6            ID             7
# Address      1056 Sanchez St    551 Alvarado St    My address    My address
# City           San Francisco      San Francisco       My City       My City
# ZIP               California           CA 94114    California    California
# Country                  USA                USA    My country    My country
# ...

# %%
df7=df7.drop(df7.columns[5],1)
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\2336048229.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7=df7.drop(df7.columns[5],1)

# %%
df7
# Out:
# ID                         1                  2                  4  \
# Address         3666 21st St     735 Dolores St       3995 23rd St
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         5                  6             7
# Address      1056 Sanchez St    551 Alvarado St    My address
# City           San Francisco      San Francisco       My City
# ZIP               California           CA 94114    California
# Country                  USA                USA    My country
# Name                 Sanchez         Richvalley       My shop
# ...

# %%
df7=df7.drop(df7.columns[5],1)
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\2336048229.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7=df7.drop(df7.columns[5],1)

# %%
df7=df7_t.T
df7
df7=df7.drop(df7.columns[5:7],1)
df7_t=df7
df7_t
df7=df7_t
df7
# Out:
# C:\Users\While\AppData\Local\Temp\ipykernel_5732\870437337.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7=df7.drop(df7.columns[5:7],1)
# ID                   1               2              4                5  \
# Address   3666 21st St  735 Dolores St   3995 23rd St  1056 Sanchez St
# City     San Francisco   San Francisco  San Francisco    San Francisco
# ZIP           CA 94114        CA 94119       CA 94114       California
# Country            USA             USA            USA              USA
# Name           Madeira     Bready Shop     Ben's Shop          Sanchez
#
# ID                     6
# Address  551 Alvarado St
# City       San Francisco
# ZIP             CA 94114
# Country              USA
# Name          Richvalley

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
type(n)
# Out:
# geopy.location.Location

# %%
import pandas
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756632001957215, -122.42941101194798, 0.0))

# %%
df.Coordinates[0].latitude
# Out:
# 37.756632001957215

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x !=None else None)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x !=None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
